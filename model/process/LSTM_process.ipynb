# %%
# 구글 드라이버 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pwd
# Out:
# '/content/drive/My Drive'

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, LSTM

# 하이퍼 파라미터
LEARNING_RATE = 0.001
N_EPOCHS = 100
N_BATCHS = 100
NUM_CLASSES = 4 # 클래스 개수
CLASS_MODE = 'categorical'

BASE_PATH = '/content/drive/MyDrive'

# %%
# %pwd
# %cd '/content/drive/MyDrive'
# Out:
# /content/drive/MyDrive

# %% [markdown]
# # 데이터 LSTM에 맞게 전처리

# %%
# 전체 csv는 80(frame수), 2의 size로 구성 가정
# 라벨링은 각 동작 csv의 라벨(동작 번호)를 통해

# 학습데이터 및 모델 경로 설정
csv_dir = '/content/drive/MyDrive/gesture_csv_624'

# (80, 2), 프레임*(x,y)로 원하는 학습데이터 형태로 분할
IMAGE_SIZE = (640, 640)
DATA_FRAME = 80
INPUT_SHAPE = (DATA_FRAME, 2) # xy쌍
data_X, data_y = [], []
label_list = [dir for dir in os.listdir(csv_dir) if os.path.isdir(os.path.join(csv_dir, dir))] # [다음, 이전, ...]
label_list.sort()

for label, label_name in enumerate(label_list):
  now_label_path = os.path.join(csv_dir, label_name)
  csv_list = [fname for fname in os.listdir(now_label_path) if os.path.splitext(fname)[-1]=='.csv']

  # csv파일 읽어오기
  for csv_name in csv_list:
    df = pd.read_csv(os.path.join(now_label_path, csv_name), header=None)

    # MinMaxScaler가 아닌 캔버스 크기 대비 위치 비율로 data 스케일링 진행
    for i in range(2):
      df[df.columns[i]] = df[df.columns[i]]/IMAGE_SIZE[i%2]
      
    data_X.append(df)
    data_y.append(label)

# label은 OneHotEncoding
data_y = keras.utils.to_categorical(data_y)

to_shuff_all = [[x,y] for x, y in zip(data_X, data_y)]
random.shuffle(to_shuff_all)
data_X = [tmp[0] for tmp in to_shuff_all]
data_y = [tmp[1] for tmp in to_shuff_all]

# train, val, test 분리 7, 2, 1
train_idx = int(len(data_y) * 0.7)
val_idx = int(len(data_y ) * 0.9)

X_train, y_train = np.array(data_X[:train_idx]), np.array(data_y[:train_idx])
X_val, y_val = np.array(data_X[train_idx:val_idx]), np.array(data_y[train_idx:val_idx])
X_test, y_test = np.array(data_X[val_idx:]), np.array(data_y[val_idx:])

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((831, 80, 2), (238, 80, 2), (119, 80, 2))

# %%
label_list
# Out:
# ['01next_csv', '02previous_csv', '03S_csv', '04W_csv']

# %% [markdown]
# # 모델 구현

# %%
def create_model():
  model = tf.keras.Sequential()
  model.add(layers.Input((DATA_FRAME,2)))
  model.add(layers.LSTM(220, activation='relu', return_sequences=True))
  model.add(layers.LSTM(220, activation='relu', return_sequences=False))
  model.add(layers.Dense(10))
  model.add(layers.BatchNormalization())
  model.add(layers.ReLU())

  model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

  return model

# %%
model = create_model()
model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 80, 220)           196240
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 220)               388080
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                2210
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 10)                40
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 10)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 44
# =================================================================
# Total params: 586,614
# Trainable params: 586,594
# Non-trainable params: 20
# _________________________________________________________________

# %%
rl_callback = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, verbose=1)
# 하이퍼 파라미터
LEARNING_RATE = 0.001
N_EPOCHS = 100
N_BATCHS = 100

N_TRAIN, N_TEST = X_train.shape[0], X_test.shape[0]
steps_per_epoch = N_TRAIN // N_BATCHS
validation_steps = int(np.ceil(N_TEST / N_BATCHS))

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(N_TRAIN).batch(N_BATCHS, drop_remainder=True).repeat()
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(N_BATCHS)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(N_BATCHS)

history = model.fit(train_dataset,
                    epochs=N_EPOCHS,
                    steps_per_epoch=steps_per_epoch,
                    validation_data=test_dataset,
                    validation_steps=validation_steps,
                    callbacks=[rl_callback])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 3s 174ms/step - loss: 1.3490 - accuracy: 0.3587 - val_loss: 1.3696 - val_accuracy: 0.2773
# Epoch 2/100
# 8/8 [==============================] - 1s 124ms/step - loss: 1.1709 - accuracy: 0.4563 - val_loss: 1.3505 - val_accuracy: 0.4202
# Epoch 3/100
# 8/8 [==============================] - 1s 124ms/step - loss: 1.0840 - accuracy: 0.4812 - val_loss: 1.3471 - val_accuracy: 0.4370
# Epoch 4/100
# 8/8 [==============================] - 1s 124ms/step - loss: 1.0519 - accuracy: 0.4787 - val_loss: 1.2752 - val_accuracy: 0.4370
# Epoch 5/100
# 8/8 [==============================] - 1s 128ms/step - loss: 1.0165 - accuracy: 0.5675 - val_loss: 1.2582 - val_accuracy: 0.3950
# Epoch 6/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.9243 - accuracy: 0.5850 - val_loss: 1.3056 - val_accuracy: 0.3109
# Epoch 7/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.8821 - accuracy: 0.6425 - val_loss: 1.2377 - val_accuracy: 0.4454
# Epoch 8/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.7868 - accuracy: 0.6762 - val_loss: 1.0931 - val_accuracy: 0.5210
# Epoch 9/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.7486 - accuracy: 0.6850 - val_loss: 1.1796 - val_accuracy: 0.6471
# Epoch 10/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.6971 - accuracy: 0.7050 - val_loss: 1.0984 - val_accuracy: 0.5462
# Epoch 11/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.6499 - accuracy: 0.7250 - val_loss: 1.0341 - val_accuracy: 0.5546
# Epoch 12/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.6307 - accuracy: 0.7237 - val_loss: 0.9703 - val_accuracy: 0.6134
# Epoch 13/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.6144 - accuracy: 0.7337 - val_loss: 0.9887 - val_accuracy: 0.5378
# Epoch 14/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.5740 - accuracy: 0.7675 - val_loss: 1.0048 - val_accuracy: 0.6387
# Epoch 15/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.5457 - accuracy: 0.7788 - val_loss: 0.9959 - val_accuracy: 0.5966
# Epoch 16/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.5537 - accuracy: 0.8200 - val_loss: 0.9565 - val_accuracy: 0.6387
# Epoch 17/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.5622 - accuracy: 0.8263 - val_loss: 0.9508 - val_accuracy: 0.6555
# Epoch 18/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.5227 - accuracy: 0.8500 - val_loss: 0.8064 - val_accuracy: 0.7059
# Epoch 19/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.4522 - accuracy: 0.8925 - val_loss: 0.7377 - val_accuracy: 0.7227
# Epoch 20/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.4326 - accuracy: 0.9050 - val_loss: 0.7447 - val_accuracy: 0.6723
# Epoch 21/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3892 - accuracy: 0.9300 - val_loss: 0.6287 - val_accuracy: 0.8487
# Epoch 22/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3323 - accuracy: 0.9475 - val_loss: 0.5679 - val_accuracy: 0.7983
# Epoch 23/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.2872 - accuracy: 0.9575 - val_loss: 0.5605 - val_accuracy: 0.9328
# Epoch 24/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.2559 - accuracy: 0.9613 - val_loss: 0.5751 - val_accuracy: 0.8992
# Epoch 25/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.2333 - accuracy: 0.9700 - val_loss: 0.3528 - val_accuracy: 0.9244
# Epoch 26/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.2008 - accuracy: 0.9775 - val_loss: 0.3899 - val_accuracy: 0.9496
# Epoch 27/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.1912 - accuracy: 0.9762 - val_loss: 0.2781 - val_accuracy: 0.9832
# Epoch 28/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.1876 - accuracy: 0.9787 - val_loss: 0.4071 - val_accuracy: 0.8824
# Epoch 29/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.2377 - accuracy: 0.9475 - val_loss: 0.4307 - val_accuracy: 0.8824
# Epoch 30/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.2364 - accuracy: 0.9475 - val_loss: 0.3406 - val_accuracy: 0.9412
# Epoch 31/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.2018 - accuracy: 0.9613 - val_loss: 0.2562 - val_accuracy: 0.9748
# Epoch 32/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.1631 - accuracy: 0.9737 - val_loss: 0.2545 - val_accuracy: 0.9412
# Epoch 33/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.1500 - accuracy: 0.9787 - val_loss: 0.2401 - val_accuracy: 0.9496
# Epoch 34/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.1316 - accuracy: 0.9825 - val_loss: 0.2416 - val_accuracy: 0.9748
# Epoch 35/100
# 8/8 [==============================] - 1s 123ms/step - loss: 0.1115 - accuracy: 0.9912 - val_loss: 0.1560 - val_accuracy: 0.9832
# Epoch 36/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0958 - accuracy: 0.9875 - val_loss: 0.1510 - val_accuracy: 0.9916
# Epoch 37/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0917 - accuracy: 0.9925 - val_loss: 0.1296 - val_accuracy: 0.9748
# Epoch 38/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0908 - accuracy: 0.9900 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 39/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0739 - accuracy: 0.9950 - val_loss: 0.1232 - val_accuracy: 0.9916
# Epoch 40/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.1999 - accuracy: 0.9525 - val_loss: 0.4131 - val_accuracy: 0.8571
# Epoch 41/100
# 8/8 [==============================] - 1s 123ms/step - loss: 0.1319 - accuracy: 0.9712 - val_loss: 0.2613 - val_accuracy: 0.9412
# Epoch 42/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.1392 - accuracy: 0.9725 - val_loss: 0.1207 - val_accuracy: 0.9748
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 43/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.1097 - accuracy: 0.9787 - val_loss: 0.1123 - val_accuracy: 0.9748
# Epoch 44/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0865 - accuracy: 0.9912 - val_loss: 0.1339 - val_accuracy: 0.9664
# Epoch 45/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0751 - accuracy: 0.9925 - val_loss: 0.1187 - val_accuracy: 0.9748
# Epoch 46/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0656 - accuracy: 0.9962 - val_loss: 0.1127 - val_accuracy: 0.9832
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 47/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0646 - accuracy: 0.9962 - val_loss: 0.1107 - val_accuracy: 0.9832
# Epoch 48/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0664 - accuracy: 0.9962 - val_loss: 0.1087 - val_accuracy: 0.9832
# Epoch 49/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0640 - accuracy: 0.9975 - val_loss: 0.1069 - val_accuracy: 0.9832
# Epoch 50/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0638 - accuracy: 0.9975 - val_loss: 0.1053 - val_accuracy: 0.9748
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 51/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0619 - accuracy: 0.9975 - val_loss: 0.1046 - val_accuracy: 0.9832
# Epoch 52/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0613 - accuracy: 0.9962 - val_loss: 0.1039 - val_accuracy: 0.9832
# Epoch 53/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0641 - accuracy: 0.9975 - val_loss: 0.1035 - val_accuracy: 0.9832
# Epoch 54/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0609 - accuracy: 0.9975 - val_loss: 0.1029 - val_accuracy: 0.9832
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 55/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0574 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9832
# Epoch 56/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0607 - accuracy: 0.9975 - val_loss: 0.1022 - val_accuracy: 0.9832
# Epoch 57/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0648 - accuracy: 0.9975 - val_loss: 0.1020 - val_accuracy: 0.9832
# Epoch 58/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0636 - accuracy: 0.9975 - val_loss: 0.1018 - val_accuracy: 0.9832
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 59/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0661 - accuracy: 0.9975 - val_loss: 0.1016 - val_accuracy: 0.9832
# Epoch 60/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0603 - accuracy: 0.9975 - val_loss: 0.1015 - val_accuracy: 0.9832
# Epoch 61/100
# 8/8 [==============================] - 1s 122ms/step - loss: 0.0612 - accuracy: 0.9975 - val_loss: 0.1014 - val_accuracy: 0.9832
# Epoch 62/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0613 - accuracy: 0.9975 - val_loss: 0.1013 - val_accuracy: 0.9832
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 63/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0612 - accuracy: 0.9962 - val_loss: 0.1012 - val_accuracy: 0.9832
# Epoch 64/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0640 - accuracy: 0.9975 - val_loss: 0.1011 - val_accuracy: 0.9832
# Epoch 65/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0624 - accuracy: 0.9975 - val_loss: 0.1010 - val_accuracy: 0.9832
# Epoch 66/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0613 - accuracy: 0.9987 - val_loss: 0.1009 - val_accuracy: 0.9832
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 67/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0590 - accuracy: 0.9975 - val_loss: 0.1008 - val_accuracy: 0.9832
# Epoch 68/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0559 - accuracy: 0.9987 - val_loss: 0.1007 - val_accuracy: 0.9832
# Epoch 69/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0626 - accuracy: 0.9962 - val_loss: 0.1007 - val_accuracy: 0.9832
# Epoch 70/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0605 - accuracy: 0.9975 - val_loss: 0.1006 - val_accuracy: 0.9832
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# Epoch 71/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0646 - accuracy: 0.9962 - val_loss: 0.1005 - val_accuracy: 0.9832
# Epoch 72/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0601 - accuracy: 0.9987 - val_loss: 0.1005 - val_accuracy: 0.9832
# Epoch 73/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0635 - accuracy: 0.9975 - val_loss: 0.1004 - val_accuracy: 0.9832
# Epoch 74/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0634 - accuracy: 0.9975 - val_loss: 0.1004 - val_accuracy: 0.9832
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# Epoch 75/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0600 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 76/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0628 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 77/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0616 - accuracy: 0.9987 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 78/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0607 - accuracy: 0.9962 - val_loss: 0.1004 - val_accuracy: 0.9832
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# Epoch 79/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0604 - accuracy: 0.9975 - val_loss: 0.1004 - val_accuracy: 0.9832
# Epoch 80/100
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0605 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 81/100
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0621 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 82/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0608 - accuracy: 0.9975 - val_loss: 0.1004 - val_accuracy: 0.9832
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# Epoch 83/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0634 - accuracy: 0.9962 - val_loss: 0.1004 - val_accuracy: 0.9832
# Epoch 84/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0627 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 85/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0615 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 86/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0611 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# Epoch 87/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0590 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 88/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0616 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 89/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0591 - accuracy: 0.9987 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 90/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0617 - accuracy: 0.9975 - val_loss: 0.1002 - val_accuracy: 0.9832
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# Epoch 91/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0659 - accuracy: 0.9962 - val_loss: 0.1002 - val_accuracy: 0.9832
# Epoch 92/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0603 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 93/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0590 - accuracy: 0.9987 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 94/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0596 - accuracy: 0.9987 - val_loss: 0.1003 - val_accuracy: 0.9832
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# Epoch 95/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0630 - accuracy: 0.9962 - val_loss: 0.1002 - val_accuracy: 0.9832
# Epoch 96/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0624 - accuracy: 0.9962 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 97/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0609 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
# Epoch 98/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0624 - accuracy: 0.9975 - val_loss: 0.1003 - val_accuracy: 0.9832
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.
# Epoch 99/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0604 - accuracy: 0.9975 - val_loss: 0.1002 - val_accuracy: 0.9832
# Epoch 100/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0620 - accuracy: 0.9962 - val_loss: 0.1002 - val_accuracy: 0.9832

# %%
model.evaluate(test_dataset)

MODEL_PATH = '/content/drive/MyDrive/LSTM_gesture_model'
# # h5형식으로 저장
# model_h5_path = os.path.join(MODEL_PATH, 'lstm_model.h5')
# Out:
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1002 - accuracy: 0.9832
# [0.10019071400165558, 0.9831932783126831]

# %%
# 학습 결과 시각화
def plot_result(history, ymin=None, ymax=None):
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)

    plt.plot(range(1,N_EPOCHS+1), history.history['loss'], label='train loss')
    plt.plot(range(1,N_EPOCHS+1), history.history['val_loss'], label='validation loss')
    plt.title('LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    if ymin!=None and ymax!=None:
        plt.ylim(ymin, ymax)
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(range(1, N_EPOCHS+1), history.history['accuracy'], label='train accuracy')
    plt.plot(range(1, N_EPOCHS+1), history.history['val_accuracy'], label='validation accuracy')
    plt.title('ACCURACY')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    if ymin!=None and ymax!=None:
        plt.ylim(ymin, ymax)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_result(history)
